# %%
import requests 
from xml.etree import ElementTree

# %%
#TODO add proxy support
proxies{}

# %%
def xml_parse(html):
    root=etree.fromstring(html, ns=True)
   
    
def parse(url):
    #Configure headers in request
    headers={
        'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'
    }
    request=requests.get(url)
    if requests.codes.ok == request.status_code:
        print('yay')
    else:
        print("Error connecting to '{}'".format(url))
    xml_parse(request)

# %%
get_url('http://malc0de.com/rss/')
# Out:
# yay

# %%
xml=ElementTree.fromstring(requests.get('http://malc0de.com/rss/').text)

# %%
for data in xml.itertext():
    print(data)
# Out:
# Malc0de Database Feed
#
#
# http://malc0de.com/database/
#
#
# Updated Feed of Malicious Executables
#
#
# en-us
#
#
# Copyright (C) 2010 malc0de.com
#
#
#
#
# nowland.com.au
#
#
# http://malc0de.com/database/index.php?search=nowland.com.au
#
#
# URL: nowland.com.au/concrete/v/_output13B9EC0.exe, IP Address: 139.162.29.216, Country: NL, ASN: 63949, MD5: 74c5ddfd3e2fd6bdd5b873f87d10c9b1
#
#
#
#
#
#
# nosharescanner.com
#
#
# http://malc0de.com/database/index.php?search=nosharescanner.com
#
#
# URL: nosharescanner.com/download/dvfoo35338982, IP Address: 104.236.87.92, Country: US, ASN: 14061, MD5: 027c11340e4eb66512d9a9b0742e6464
#
#
#
#
#
#
# infermierifktmatuziani.org
#
#
# http://malc0de.com/database/index.php?search=infermierifktmatuziani.org
#
#
# URL: infermierifktmatuziani.org/counter/index.html?2, IP Address: 85.235.154.17, Country: IT, ASN: 31034, MD5: ed3421ff73709830c46b31188fe0d73e
#
#
#
#
#
#
# flipcoin.co
#
#
# http://malc0de.com/database/index.php?search=flipcoin.co
#
#
# ...
